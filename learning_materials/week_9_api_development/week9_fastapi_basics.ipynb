# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (0.121.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Collecting pyngrok
#   Downloading pyngrok-7.4.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.38.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.49.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi) (2.11.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.0.3)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.3.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)
# Downloading pyngrok-7.4.1-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.4.1

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import nest_asyncio

nest_asyncio.apply()

app = FastAPI()


# Define endpoints
@app.get("/")
def read_root():
    return {"message": "Banking77 API"}


@app.get("/health")
def health_check():
    return {"status": "healthy"}


class PredictionRequest(BaseModel):
    text: str
    max_length: int = 128


@app.post("/predict")
def predict(request: PredictionRequest):
    return {
        "prediction": "balance_inquiry",
        "confidence": 0.87,
        "status": "mock_response",
    }

# %%
from pyngrok import ngrok
import uvicorn

ngrok.set_auth_token("AUTH_TOKEN")
public_url = ngrok.connect(8000)
print("Public URL:", public_url)

config = uvicorn.Config(app, host="0.0.0.0", port=8000, log_level="info")
server = uvicorn.Server(config)
await server.serve()
# Out:
# Public URL: NgrokTunnel: "https://nikolai-multinucleolate-denver.ngrok-free.dev" -> "http://localhost:8000"
# INFO:     Started server process [1286]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     2a06:5900:c09a:e300:604b:5159:5b21:b66f:0 - "GET / HTTP/1.1" 200 OK
# INFO:     2a06:5900:c09a:e300:604b:5159:5b21:b66f:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     2a06:5900:c09a:e300:604b:5159:5b21:b66f:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     2a06:5900:c09a:e300:604b:5159:5b21:b66f:0 - "GET /health HTTP/1.1" 200 OK
# INFO:     2a06:5900:c09a:e300:604b:5159:5b21:b66f:0 - "GET /predict HTTP/1.1" 405 Method Not Allowed
# WARNING:pyngrok.process.ngrok:t=2025-11-06T22:04:01+0000 lvl=warn msg="Stopping forwarder" name=http-8000-cc8622ad-6815-4ee6-9fc7-487c4ce8ffda acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2025-11-06T22:04:01+0000 lvl=warn msg="Error restarting forwarder" name=http-8000-cc8622ad-6815-4ee6-9fc7-487c4ce8ffda err="failed to start tunnel: session closed"
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1286]
